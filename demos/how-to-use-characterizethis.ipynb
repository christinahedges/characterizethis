# %%
% load_ext autoreload
# %autoreload 2
import characterizethis as CT
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = CT.data()

# %%
CT.plot_hist(keplerk2=True);

# %%
CT.top(keplerk2=True)
# Out:
#   pl_hostname pl_letter   st_h       pl_eqt    pl_rade   pl_bmasse  \
# 0     GJ 9827         b  7.379  1172.000000   1.625302    3.419834
# 1     GJ 9827         d  7.379   680.000000   2.073661    5.199673
# 2      K2-232         b  8.480  1030.000000  11.208981  126.495706
# 3    HD 89345         b  7.766  1089.000000   7.397927   34.961125
# 4   WASP-85 A         b  8.925  1452.000000  13.899136  402.052934
# 5     HD 3167         c  7.203   500.000000   3.015216    9.798650
# 6    Wolf 503         b  7.774   805.000000   2.028826    4.767426
# 7       K2-31         b  8.942  1516.013893  11.881520  563.827593
# 8       K2-24         c  9.294   560.000000   8.104093   25.998364
# 9   HD 106315         c  7.962   804.000000   4.315458   17.162734
#
#    pl_density  pl_orbper    pl_trandep       delta        snr pl_facility  \
# 0    4.377099   1.208980  5.860000e+04  239.673615  22.163117          K2
# 1    3.204396   6.201467  9.570000e+04  181.742489  19.299629          K2
# ...

# %%
plt.scatter(df.pl_rade, df.pl_bmasse, s=(df.pl_trandep)*1e2)
plt.yscale('log')
plt.xscale('log')

# %%
t = df[(df.pl_eqt > 500) & (df.pl_eqt < 1000) & (df.mu == 2)]

# %%
t.sort_values('st_h')[['pl_hostname', 'pl_letter', 'pl_rade', 'pl_bmasse','st_optmag', 'st_h', 'pl_orbper', 'pl_disc']]
# Out:
#          pl_hostname pl_letter    pl_rade    pl_bmasse  st_optmag    st_h  \
# 1101        HD 97658         b   2.353886     9.534852      7.710   5.821
# 997           GJ 436         b   4.169741    22.247988     10.670   6.319
# 1198        HD 17156         b  12.329879  1115.577707      8.172   6.857
# 91          HAT-P-11         b   4.360294    26.697586      9.174   7.131
# 2765         GJ 9827         d   2.073661     5.199673     10.250   7.379
# 1763         WASP-69         b  12.441969    92.170238      9.870   7.543
# 2647        Wolf 503         b   2.028826     4.767426     10.260   7.774
# 2725       HD 106315         c   4.315458    17.162734      8.951   7.962
# 85        HIP 116454         b   2.465976    12.713136     10.190   8.140
# 1902         GJ 3470         b   3.878307    13.666621     12.330   8.206
# 1620          WASP-8         b  12.666148   807.284153      9.790   8.218
# 2138           K2-65         b   1.580466     3.121075     10.801   8.457
# ...

# %%
df.pl_disc
# Out:
# 0       2014
# 1       2014
# 2       2014
# 3       2014
# 4       2014
# 5       2014
# 6       2014
# 7       2013
# 8       2014
# 9       2014
# 10      2014
# 11      2014
# 12      2014
# 13      2014
# 14      2014
# 15      2014
# 16      2014
# 17      2014
# 18      2014
# 19      2014
# 20      2014
# 21      2014
# 22      2014
# 23      2014
# 24      2014
# 25      2014
# 26      2014
# 27      2014
# 28      2014
# 29      2014
#         ...
# 2948    2018
# 2949    2018
# 2950    2018
# 2951    2018
# 2952    2018
# 2953    2018
# 2954    2018
# 2955    2018
# 2956    2018
# 2957    2018
# 2958    2018
# 2959    2018
# 2960    2018
# 2961    2018
# 2962    2018
# 2963    2018
# 2964    2018
# 2965    2018
# 2966    2018
# 2967    2018
# 2968    2018
# 2969    2015
# 2970    2018
# 2971    2018
# 2972    2018
# 2973    2018
# 2974    2018
# 2975    2018
# 2976    2018
# 2977    2018
# Name: pl_disc, Length: 2978, dtype: int64
